# %% [markdown]
# # Name: Dnyanal Shelke
# # TY D Roll no:22
# # Gr No:11810571

# %% [markdown]
# ## Assignment 1: Descriptive Statistics
# ### IRIS Dataset

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv(r"C:\Users\hp\Documents\DS LAB\datasets_IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Finding mean, median, mode and midrange

# %%
print("Sepal Length in cm")
print("\tMean = "+str(np.mean(df['sepal_length'])))
print("\tMedian = "+str(np.median(df['sepal_length'])))
print("\tMode = "+str(stats.mode(df['sepal_length'])))
print("\tMidRange = ",(min(df['sepal_length'])+max(df['sepal_length']))/2)
print("\n")

print("Sepal Width in cm")
print("\tMean = "+str(np.mean(df['sepal_width'])))
print("\tMedian = "+str(np.median(df['sepal_width'])))
print("\tMode = "+str(stats.mode(df['sepal_width'])))
print("\tMidRange = ",(min(df['sepal_width'])+max(df['sepal_width']))/2)
print("\n")


print("Petal Length in cm")
print("\tMean = "+str(np.mean(df['petal_length'])))
print("\tMedian = "+str(np.median(df['petal_length'])))
print("\tMode = "+str(stats.mode(df['petal_length'])))
print("\tMidRange = ",(min(df['petal_length'])+max(df['petal_length']))/2)
print("\n")


print("Petal Width in cm")
print("\tMean = "+str(np.mean(df['petal_width'])))
print("\tMedian = "+str(np.median(df['petal_width'])))
print("\tMode = "+str(stats.mode(df['petal_width'])))
print("\tMidRange = ",(min(df['petal_width'])+max(df['petal_width']))/2)
print("\n")
# Out:
# Sepal Length in cm
# 	Mean = 5.843333333333335
# 	Median = 5.8
# 	Mode = ModeResult(mode=array([5.]), count=array([10]))
# 	MidRange =  6.1
#
#
# Sepal Width in cm
# 	Mean = 3.0540000000000007
# 	Median = 3.0
# 	Mode = ModeResult(mode=array([3.]), count=array([26]))
# 	MidRange =  3.2
#
#
# Petal Length in cm
# 	Mean = 3.7586666666666693
# 	Median = 4.35
# 	Mode = ModeResult(mode=array([1.5]), count=array([14]))
# 	MidRange =  3.95
#
#
# Petal Width in cm
# 	Mean = 1.1986666666666672
# 	Median = 1.3
# 	Mode = ModeResult(mode=array([0.2]), count=array([28]))
# 	MidRange =  1.3

# %% [markdown]
# # Box Plot of Attributes

# %%
plt.subplot(1,2,1)
plt.boxplot(df['sepal_length'],patch_artist=True)
plt.title('Sepal Length(cm)')
plt.subplot(1,2,2)
plt.boxplot(df['sepal_width'],patch_artist=True)
plt.title('Sepal Width(cm)')
plt.show() 
plt.subplot(1,2,1)
plt.boxplot(df['petal_length'],patch_artist=True)
plt.title('Petal Length(cm)')
plt.subplot(1,2,2)
plt.boxplot(df['petal_width'],patch_artist=True)
plt.title('Petal Width(cm)')
plt.show()

# %% [markdown]
# # Identifying and Removing Outliers

# %%
Q1 = df['sepal_width'].quantile(0.25)
Q3 = df['sepal_width'].quantile(0.75)
IQR = Q3 - Q1

# %%
gk=df[(df['sepal_width'] < Q1-1.5*IQR ) | (df['sepal_width'] > Q3+1.5*IQR)]['sepal_width']
print(gk)
# Out:
# 15    4.4
# 32    4.1
# 33    4.2
# 60    2.0
# Name: sepal_width, dtype: float64

# %%
gk = list(gk.index)

# %%
dff = df.drop(gk)
dff
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %% [markdown]
# # Boxplot After removing Outliers

# %%
plt.subplot(1,2,1)
plt.boxplot(dff['sepal_length'],patch_artist=True)
plt.title('Sepal Length(cm)')
plt.subplot(1,2,2)
plt.boxplot(dff['sepal_width'],patch_artist=True)
plt.title('Sepal Width(cm)')
plt.show() 
plt.subplot(1,2,1)
plt.boxplot(dff['petal_length'],patch_artist=True)
plt.title('Petal Length(cm)')
plt.subplot(1,2,2)
plt.boxplot(dff['petal_width'],patch_artist=True)
plt.title('Petal Width(cm)')
plt.show()

# %% [markdown]
# # Finding mean, median and mode after removing Outliers

# %%
print("Sepal Length in Cm")
print("\tMean = "+str(np.mean(dff['sepal_length'])))
print("\tMedian = "+str(np.median(dff['sepal_length'])))
print("\tMode = "+str(stats.mode(dff['sepal_length'])))
print("\tMidRange = ",(min(df['sepal_length'])+max(df['sepal_length']))/2)
print("\n")

print("Sepal Width in Cm")
print("\tMean = "+str(np.mean(dff['sepal_width'])))
print("\tMedian = "+str(np.median(dff['sepal_width'])))
print("\tMode = "+str(stats.mode(dff['sepal_width'])))
print("\tMidRange = ",(min(df['sepal_width'])+max(df['sepal_width']))/2)
print("\n")


print("Petal Length in Cm")
print("\tMean = "+str(np.mean(dff['petal_length'])))
print("\tMedian = "+str(np.median(dff['petal_length'])))
print("\tMode = "+str(stats.mode(dff['petal_length'])))
print("\tMidRange = ",(min(df['petal_length'])+max(df['petal_length']))/2)
print("\n")


print("Petal Width in Cm")
print("\tMean = "+str(np.mean(dff['petal_width'])))
print("\tMedian = "+str(np.median(dff['petal_width'])))
print("\tMode = "+str(stats.mode(dff['petal_width'])))
print("\tMidRange = ",(min(df['petal_width'])+max(df['petal_width']))/2)
print("\n")
# Out:
# Sepal Length in Cm
# 	Mean = 5.856849315068494
# 	Median = 5.8
# 	Mode = ModeResult(mode=array([5.]), count=array([9]))
# 	MidRange =  6.1
#
#
# Sepal Width in Cm
# 	Mean = 3.036986301369864
# 	Median = 3.0
# 	Mode = ModeResult(mode=array([3.]), count=array([26]))
# 	MidRange =  3.2
#
#
# Petal Length in Cm
# 	Mean = 3.8075342465753454
# 	Median = 4.4
# 	Mode = ModeResult(mode=array([1.5]), count=array([12]))
# 	MidRange =  3.95
#
#
# Petal Width in Cm
# 	Mean = 1.2198630136986308
# 	Median = 1.3
# 	Mode = ModeResult(mode=array([0.2]), count=array([27]))
# 	MidRange =  1.3

# %% [markdown]
# # Finding the standard deviation and variance of those observations having highest mode with respect to species.
# ## Finding the highest Mode with respect to species.

# %%
modeSL1 = stats.mode(df.groupby('species').get_group('Iris-setosa')['sepal_length'])
modeSL2 = stats.mode(df.groupby('species').get_group('Iris-versicolor')['sepal_length'])
modeSL3 = stats.mode(df.groupby('species').get_group('Iris-virginica')['sepal_length'])
print(modeSL1[0][0],modeSL2[0][0],modeSL3[0][0])
print("Max mode : "+str(max(modeSL1[0][0],modeSL2[0][0],modeSL3[0][0])))
print("\n")

modeSW1 = stats.mode(df.groupby('species').get_group('Iris-setosa')['sepal_width'])
modeSW2 = stats.mode(df.groupby('species').get_group('Iris-versicolor')['sepal_width'])
modeSW3 = stats.mode(df.groupby('species').get_group('Iris-virginica')['sepal_width'])
print(modeSW1[0][0],modeSW2[0][0],modeSW3[0][0])
print("Max mode : "+str(max(modeSW1[0][0],modeSW2[0][0],modeSW3[0][0])))
print("\n")

modePL1 = stats.mode(df.groupby('species').get_group('Iris-setosa')['petal_length'])
modePL2 = stats.mode(df.groupby('species').get_group('Iris-versicolor')['petal_length'])
modePL3 = stats.mode(df.groupby('species').get_group('Iris-virginica')['petal_length'])
print(modePL1[0][0],modePL2[0][0],modePL3[0][0])
print("Max mode : "+str(max(modePL1[0][0],modePL2[0][0],modePL3[0][0])))
print("\n")

modePW1 = stats.mode(df.groupby('species').get_group('Iris-setosa')['petal_width'])
modePW2 = stats.mode(df.groupby('species').get_group('Iris-versicolor')['petal_width'])
modePW3 = stats.mode(df.groupby('species').get_group('Iris-virginica')['petal_width'])
print(modePW1[0][0],modePW2[0][0],modePW3[0][0])
print("Max mode : "+str(max(modePW1[0][0],modePW2[0][0],modePW3[0][0])))
print("\n")
# Out:
# 5.0 5.5 6.3
# Max mode : 6.3
#
#
# 3.4 3.0 3.0
# Max mode : 3.4
#
#
# 1.5 4.5 5.1
# Max mode : 5.1
#
#
# 0.2 1.3 1.8
# Max mode : 1.8

# %% [markdown]
# # Standard Deviation

# %%
print("Sepal Length in Cm : "+str(np.std(df.groupby('species').get_group('Iris-virginica')['sepal_length'])))
print("Sepal Width  in Cm : "+str(np.std(df.groupby('species').get_group('Iris-setosa')['sepal_width'])))
print("Petal Length in Cm : "+str(np.std(df.groupby('species').get_group('Iris-virginica')['petal_length'])))
print("Petal Width  in Cm : "+str(np.std(df.groupby('species').get_group('Iris-virginica')['petal_width'])))
# Out:
# Sepal Length in Cm : 0.6294886813914925
# Sepal Width  in Cm : 0.37719490982779713
# Petal Length in Cm : 0.5463478745268441
# Petal Width  in Cm : 0.2718896835115301

# %% [markdown]
# # Variance

# %%
print("Sepal Length in Cm : "+str(np.var(df.groupby('species').get_group('Iris-virginica')['sepal_length'])))
print("Sepal Width  in Cm : "+str(np.var(df.groupby('species').get_group('Iris-setosa')['sepal_width'])))
print("Petal Length in Cm : "+str(np.var(df.groupby('species').get_group('Iris-virginica')['petal_length'])))
print("Petal Width  in Cm : "+str(np.var(df.groupby('species').get_group('Iris-virginica')['petal_width'])))
# Out:
# Sepal Length in Cm : 0.39625599999999994
# Sepal Width  in Cm : 0.142276
# Petal Length in Cm : 0.2984960000000002
# Petal Width  in Cm : 0.07392399999999999

# %% [markdown]
# # Checking for balanced Dataset

# %%
df.groupby('species').count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %% [markdown]
# # Scatter plot of sepal length vs sepal width

# %%
plt.title('Scatter Plot of Sepal Length in cm VS Sepal Width in cm')
sns.scatterplot(x = "sepal_length", y = "sepal_width", data = df, hue = "species")

# %% [markdown]
# # Scatter plot of sepal length vs sepal width for each flower
# ## Iris-setosa

# %%
plt.xlabel("Sepal Length") 
plt.ylabel("Sepal Width") 
j = df.groupby('species').get_group('Iris-setosa')['sepal_length']
k = df.groupby('species').get_group('Iris-setosa')['sepal_width']
plt.scatter(j, k, c=k, cmap='Spectral')
plt.colorbar()
plt.title('Scatter Plot of Sepal Length in cm VS Sepal Width in cm of Iris-setosa')
plt.show()

# %% [markdown]
# ## Iris-versicolor

# %%
plt.xlabel("Sepal Length") 
plt.ylabel("Sepal Width") 
j = df.groupby('species').get_group('Iris-versicolor')['sepal_length']
k = df.groupby('species').get_group('Iris-versicolor')['sepal_width']
plt.scatter(j, k, c=k, cmap='Spectral')
plt.colorbar()
plt.title('Scatter Plot of Sepal Length in cm VS Sepal Width in cm of Iris-versicolor')
plt.show()

# %% [markdown]
# ## Iris-virginica

# %%
plt.xlabel("Sepal Length") 
plt.ylabel("Sepal Width") 
j = df.groupby('species').get_group('Iris-virginica')['sepal_length']
k = df.groupby('species').get_group('Iris-virginica')['sepal_width']
plt.scatter(j, k, c=k, cmap='Spectral')
plt.colorbar()
plt.title('Scatter Plot of Sepal Length in cm VS Sepal Width in cm of Iris-virginica')
plt.show()

# %% [markdown]
# # Box plots of attributes by Iris species
# ## Sepal Length Cm of Species

# %%
print("\t\t\t\t  Box Plot of Sepal Length in cm of Species")
plt.subplots_adjust(hspace=0.4, wspace=0.4)

i = df.groupby('species').get_group('Iris-setosa')['sepal_length']
plt.subplot(1,3,1)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-setosa')
i = df.groupby('species').get_group('Iris-versicolor')['sepal_length']
plt.subplot(1,3,2)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-versicolor')
i = df.groupby('species').get_group('Iris-virginica')['sepal_length']
plt.subplot(1,3,3)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-virginica')
plt.show()
# Out:
# 				  Box Plot of Sepal Length in cm of Species

# %% [markdown]
# ## Sepal Width Cm of Species

# %%
plt.subplots_adjust(hspace=0.4, wspace=0.4)
print("\t\t\t\t  Box Plot of Sepal Width in cm of Species")
i = df.groupby('species').get_group('Iris-setosa')['sepal_width']
plt.subplot(1,3,1)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-setosa')
i = df.groupby('species').get_group('Iris-versicolor')['sepal_width']
plt.subplot(1,3,2)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-versicolor')
i = df.groupby('species').get_group('Iris-virginica')['sepal_width']
plt.subplot(1,3,3)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-virginica')
plt.show()
# Out:
# 				  Box Plot of Sepal Width in cm of Species

# %% [markdown]
# ## Petal Length Cm of Species

# %%
print("\t\t\t\t  Box Plot of Petal Length in Cm of Species")
i = df.groupby('species').get_group('Iris-setosa')['petal_length']
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.subplot(1,3,1)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-setosa')
i = df.groupby('species').get_group('Iris-versicolor')['petal_length']
plt.subplot(1,3,2)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-versicolor')
i = df.groupby('species').get_group('Iris-virginica')['petal_length']
plt.subplot(1,3,3)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-virginica')
plt.show()
# Out:
# 				  Box Plot of Petal Length in Cm of Species

# %% [markdown]
# ## Petal Width Cm of Species

# %%
print("\t\t\t\t  Box Plot of Petal Width in cm of Species")
i = df.groupby('species').get_group('Iris-setosa')['petal_width']
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.subplot(1,3,1)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-setosa')
i = df.groupby('species').get_group('Iris-versicolor')['petal_width']
plt.subplot(1,3,2)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-versicolor')
i = df.groupby('species').get_group('Iris-virginica')['petal_width']
plt.subplot(1,3,3)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-virginica')
plt.show()
# Out:
# 				  Box Plot of Petal Width in cm of Species

# %% [markdown]
# # Boxplot of petal length by Iris species

# %%
print("\t\t\t\t  Box Plot of Petal Length in cm of Species")
i = df.groupby('species').get_group('Iris-setosa')['petal_length']
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.subplot(1,3,1)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-setosa')
i = df.groupby('species').get_group('Iris-versicolor')['petal_length']
plt.subplot(1,3,2)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-versicolor')
i = df.groupby('species').get_group('Iris-virginica')['petal_length']
plt.subplot(1,3,3)
plt.boxplot(i,patch_artist=True)
plt.title('Iris-virginica')
plt.show()
# Out:
# 				  Box Plot of Petal Length in cm of Species

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv(r"C:\Users\hp\Documents\DS LAB\glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # Box plot with the five number summary

# %%
plt.rcParams["figure.figsize"] = (10,8)
plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df['RI'],patch_artist=True)
plt.title('RI')
plt.subplot(1,3,2)
plt.boxplot(df['Na'],patch_artist=True)
plt.title('Na')
plt.subplot(1,3,3)
plt.boxplot(df['Mg'],patch_artist=True)
plt.title('Mg')
plt.show()

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df['Al'],patch_artist=True)
plt.title('Al')
plt.subplot(1,3,2)
plt.boxplot(df['Si'],patch_artist=True)
plt.title('Si')
plt.subplot(1,3,3)
plt.boxplot(df['K'],patch_artist=True)
plt.title('K')
plt.show()

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df['Ca'],patch_artist=True)
plt.title('Ca')
plt.subplot(1,3,2)
plt.boxplot(df['Ba'],patch_artist=True)
plt.title('Ba')
plt.subplot(1,3,3)
plt.boxplot(df['Fe'],patch_artist=True)
plt.title('Fe')
plt.show()

# %% [markdown]
# # Removing the outliers using IQR

# %%
Q1 =  df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
gk=df[(df< Q1-1.5*IQR ) | (df > Q3+1.5*IQR)]
ot = gk.notnull()

# %% [markdown]
# # Box plot with the dataset after the removal of outliers

# %%
plt.rcParams["figure.figsize"] = (10,8)
otRI = list(ot[ot['RI']==True].index)
df1 = df.drop(otRI)

otNa = list(ot[ot['Na']==True].index)
df2 = df.drop(otNa)

otMg = list(ot[ot['Mg']==True].index)
df3 = df.drop(otMg)

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df1['RI'],patch_artist=True)
plt.title('RI')
plt.subplot(1,3,2)
plt.boxplot(df2['Na'],patch_artist=True)
plt.title('Na')
plt.subplot(1,3,3)
plt.boxplot(df3['Mg'],patch_artist=True)
plt.title('Mg')
plt.show()


otAl = list(ot[ot['Al']==True].index)
df4 = df.drop(otAl)

otSi = list(ot[ot['Si']==True].index)
df5 = df.drop(otSi)

otK = list(ot[ot['K']==True].index)
df6 = df.drop(otK)


plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df4['Al'],patch_artist=True)
plt.title('Al')
plt.subplot(1,3,2)
plt.boxplot(df5['Si'],patch_artist=True)
plt.title('Si')
plt.subplot(1,3,3)
plt.boxplot(df6['K'],patch_artist=True)
plt.title('K')
plt.show()

otCa = list(ot[ot['Ca']==True].index)
df7 = df.drop(otCa)

otBa = list(ot[ot['Ba']==True].index)
df8 = df.drop(otBa)

otFe = list(ot[ot['Fe']==True].index)
df9 = df.drop(otFe)

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,3,1)
plt.boxplot(df7['Ca'],patch_artist=True)
plt.title('Ca')
plt.subplot(1,3,2)
plt.boxplot(df8['Ba'],patch_artist=True)
plt.title('Ba')
plt.subplot(1,3,3)
plt.boxplot(df9['Fe'],patch_artist=True)
plt.title('Fe')
plt.show()

# %% [markdown]
# # Compare the results

# %%
plt.rcParams["figure.figsize"] = (10,8)
plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,2,1)
plt.boxplot(df['RI'],patch_artist=True)
plt.boxplot(df1['RI'])
plt.title('RI')
plt.subplot(1,2,2)
plt.boxplot(df['Na'],patch_artist=True)
plt.boxplot(df2['Na'])
plt.title('Na')
plt.show()

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,2,1)
plt.boxplot(df['Mg'],patch_artist=True)
plt.boxplot(df3['Mg'])
plt.title('Mg')
plt.subplot(1,2,2)
plt.boxplot(df['Al'],patch_artist=True)
plt.boxplot(df4['Al'])
plt.title('Al')
plt.show()

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,2,1)
plt.boxplot(df['Si'],patch_artist=True)
plt.boxplot(df5['Si'])
plt.title('Si')
plt.subplot(1,2,2)
plt.boxplot(df['K'],patch_artist=True)
plt.boxplot(df6['K'])
plt.title('K')
plt.show()

plt.subplots_adjust(hspace=0.5, wspace=1)
plt.subplot(1,2,1)
plt.boxplot(df['Ba'],patch_artist=True)
plt.boxplot(df8['Ba'])
plt.title('Ba')
plt.subplot(1,2,2)
plt.boxplot(df['Fe'],patch_artist=True)
plt.boxplot(df9['Fe'])
plt.title('Fe')
plt.show()
